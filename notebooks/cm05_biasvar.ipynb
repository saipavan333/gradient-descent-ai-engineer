# %% [markdown]
# # 3.5 Bias–variance tradeoff & overfitting
#
# Gradient Descent · Track 3 (Classical ML). Runnable companion — outputs match the lesson.

# %% [markdown]
# ## Watch test error turn into a U as model complexity grows

# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split

rng = np.random.default_rng(0)
X = np.sort(rng.uniform(-3, 3, 60)).reshape(-1, 1)
y = np.sin(X[:, 0]) + rng.normal(0, 0.3, 60)
X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.4, random_state=0)

for deg in [1, 3, 5, 9, 15]:
    m = make_pipeline(PolynomialFeatures(deg), LinearRegression()).fit(X_tr, y_tr)
    tr = ((m.predict(X_tr) - y_tr) ** 2).mean()
    te = ((m.predict(X_te) - y_te) ** 2).mean()
    print(f"degree {deg:2d}:  train MSE {tr:.3f}   test MSE {te:.3f}")
# Out:
# degree  1:  train MSE 0.237   test MSE 0.255
# degree  3:  train MSE 0.102   test MSE 0.106
# degree  5:  train MSE 0.089   test MSE 0.129
# degree  9:  train MSE 0.083   test MSE 1.355
# degree 15:  train MSE 0.059   test MSE 499.265

# %% [markdown]
# Training MSE falls forever; test MSE bottoms at degree 3, then explodes — the bias-variance U.
