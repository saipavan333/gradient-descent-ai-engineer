# %% [markdown]
# # 6.7 Scaling laws & emergent behavior
#
# Gradient Descent · Track 6 (LLMs & Generative AI). Runnable companion — outputs match the lesson.

# %% [markdown]
# ## Forecasting loss from a scaling law: loss = a * C^(-b)

# %%
a, b = 2.0, 0.05
for C in [1e18, 1e20, 1e22]:
    print(f"compute {C:.0e}:  predicted loss {a * C ** (-b):.3f}")
# Out:
# compute 1e+18:  predicted loss 0.252
# compute 1e+20:  predicted loss 0.200
# compute 1e+22:  predicted loss 0.159
