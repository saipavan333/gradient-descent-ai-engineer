# %% [markdown]
# # 3.9 Support Vector Machines
#
# Gradient Descent · Track 3 (Classical ML). Runnable companion — outputs match the lesson.

# %% [markdown]
# ## Linear vs RBF kernel on the two-moons dataset

# %%
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

X, y = make_moons(n_samples=300, noise=0.2, random_state=0)
X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.3, random_state=0)
for kernel in ["linear", "rbf"]:
    svm = SVC(kernel=kernel).fit(X_tr, y_tr)
    print(f"{kernel:7s} SVM test accuracy: {svm.score(X_te, y_te):.3f}")
# Out:
# linear  SVM test accuracy: 0.867
# rbf     SVM test accuracy: 1.000
